# %% [markdown]
# <h3> Data Import and Clean-up </h3>

# %%
import pandas as pd
import numpy as np

##Note: this prints the dataframe at the end of each step, if you don't want to see every step, you can comment out 
##lines reading print(df) without impacting the program

##Step 1: import data and create dataframe
data = pd.read_csv('Breast-Cancer-Wisconsin.csv')

df = pd.DataFrame(data)

##print(df)

##Step 2: replace ? with Nan
df['A7'] = df['A7'].replace('?', np.NaN)

##print(df)
##print(df.dtypes)

##Step 3: change A7 datatype to numeric

df['A7'] = pd.to_numeric(df['A7'])

##print(df)
##print(df.dtypes)

##Step 4: Count NaN
print("Number of NaN entries by column: ")
print(df.isnull().sum())

##Step 5: Calculate Column Means
print(df.mean(skipna='True'))

##Step 6: Replace NaN with Column Mean
df.fillna(value=(df.mean(skipna='True')))
# Out:
# Number of NaN entries by column:
# Scn       0
# A2        0
# A3        0
# A4        0
# A5        0
# A6        0
# A7       16
# A8        0
# A9        0
# A10       0
# CLASS     0
# dtype: int64
# Scn      1.071704e+06
# A2       4.417740e+00
# A3       3.134478e+00
# A4       3.207439e+00
# A5       2.806867e+00
# A6       3.216023e+00
# A7       3.544656e+00
# A8       3.437768e+00
# A9       2.866953e+00
# A10      1.589413e+00
# CLASS    2.689557e+00
# dtype: float64
#          Scn  A2  A3  A4  A5  A6         A7  A8  A9  A10  CLASS
# 0    1000025   5   1   1   1   2   1.000000   3   1    1      2
# 1    1002945   5   4   4   5   7  10.000000   3   2    1      2
# 2    1015425   3   1   1   1   2   2.000000   3   1    1      2
# 3    1016277   6   8   8   1   3   4.000000   3   7    1      2
# 4    1017023   4   1   1   3   2   1.000000   3   1    1      2
# 5    1017122   8  10  10   8   7  10.000000   9   7    1      4
# ...

# %% [markdown]
# <h3> Summary Statistics</h3>

# %%
#step 5,6 - summary statistics
print('The summary statistics for the dataframe:')
print(df.describe())
print('\nThe number of rows in the dataframe:', len(df))
print('The number of columns in the dataframe:', len(df.columns))

#step 7 - unique ID values
print('The number of unique ID values:', df['Scn'].nunique())
# Out:
# The summary statistics for the dataframe:
#                 Scn          A2          A3          A4          A5  \
# count  6.990000e+02  699.000000  699.000000  699.000000  699.000000
# mean   1.071704e+06    4.417740    3.134478    3.207439    2.806867
# std    6.170957e+05    2.815741    3.051459    2.971913    2.855379
# min    6.163400e+04    1.000000    1.000000    1.000000    1.000000
# 25%    8.706885e+05    2.000000    1.000000    1.000000    1.000000
# 50%    1.171710e+06    4.000000    1.000000    1.000000    1.000000
# 75%    1.238298e+06    6.000000    5.000000    5.000000    4.000000
# max    1.345435e+07   10.000000   10.000000   10.000000   10.000000
#
#                A6          A7          A8          A9         A10       CLASS
# count  699.000000  683.000000  699.000000  699.000000  699.000000  699.000000
# mean     3.216023    3.544656    3.437768    2.866953    1.589413    2.689557
# std      2.214300    3.643857    2.438364    3.053634    1.715078    0.951273
# ...

# %% [markdown]
# <h3>Histograms</h3>

# %%
#step 7 - histograms for relevant columns
import matplotlib.pyplot as plt
hist = df.loc[:, 'A2':'A10'].hist(grid=False, figsize=(10,10), layout=(3,3), alpha = .75, color='c')
plt.show()

# %% [markdown]
# <h3> Bar Charts </h3>
# <h5> Replace the 2 and 4 values with the categories that they represent, and then plot a bar chart </h5>

# %%
class_counts = df.groupby(['CLASS'], as_index=False).count()
class_counts['CLASS'] = class_counts['CLASS'].replace(2, 'Benign').replace(4,'Malignant')
barx = class_counts['CLASS']
bary = class_counts['Scn']
plt.bar(barx,bary,color=['green', 'red'])
plt.title('Class Counts')
plt.xlabel('Category')
plt.ylabel('Count')
# Out:
# Text(0,0.5,'Count')

# %% [markdown]
# <h3> Scatterplot</h3>
# <h5>Select two columns and create a scatterplot</h5>

# %%
scatterx = df['A9']
scattery = df['A10']
plt.scatter(scatterx, scattery, color='red')
plt.title('Normal Nuclei and Mitoses')
plt.xlabel('Normal Nuclei')
plt.ylabel('Mitoses')
# Out:
# Text(0,0.5,'Mitoses')

# %% [markdown]
# <h3> Summary Statistics</h3>
# <h5> Explore descriptive statistics and correlation matrix of the dataset </h5>

# %%
df.describe()
# Out:
#                 Scn          A2          A3          A4          A5  \
# count  6.990000e+02  699.000000  699.000000  699.000000  699.000000
# mean   1.071704e+06    4.417740    3.134478    3.207439    2.806867
# std    6.170957e+05    2.815741    3.051459    2.971913    2.855379
# min    6.163400e+04    1.000000    1.000000    1.000000    1.000000
# 25%    8.706885e+05    2.000000    1.000000    1.000000    1.000000
# 50%    1.171710e+06    4.000000    1.000000    1.000000    1.000000
# 75%    1.238298e+06    6.000000    5.000000    5.000000    4.000000
# max    1.345435e+07   10.000000   10.000000   10.000000   10.000000
#
#                A6          A7          A8          A9         A10       CLASS
# count  699.000000  683.000000  699.000000  699.000000  699.000000  699.000000
# mean     3.216023    3.544656    3.437768    2.866953    1.589413    2.689557
# std      2.214300    3.643857    2.438364    3.053634    1.715078    0.951273
# ...

# %%
df.corr()
# Out:
#             Scn        A2        A3        A4        A5        A6        A7  \
# Scn    1.000000 -0.055308 -0.041603 -0.041576 -0.064878 -0.045528 -0.099248
# A2    -0.055308  1.000000  0.644913  0.654589  0.486356  0.521816  0.593091
# A3    -0.041603  0.644913  1.000000  0.906882  0.705582  0.751799  0.691709
# A4    -0.041576  0.654589  0.906882  1.000000  0.683079  0.719668  0.713878
# A5    -0.064878  0.486356  0.705582  0.683079  1.000000  0.599599  0.670648
# A6    -0.045528  0.521816  0.751799  0.719668  0.599599  1.000000  0.585716
# A7    -0.099248  0.593091  0.691709  0.713878  0.670648  0.585716  1.000000
# A8    -0.060051  0.558428  0.755721  0.735948  0.666715  0.616102  0.680615
# A9    -0.052072  0.535835  0.722865  0.719446  0.603352  0.628881  0.584280
# A10   -0.034901  0.350034  0.458693  0.438911  0.417633  0.479101  0.339210
# CLASS -0.080226  0.716001  0.817904  0.818934  0.696800  0.682785  0.822696
#
#              A8        A9       A10     CLASS
# ...

# %% [markdown]
# <body> According the exploratory analysis, the dataset has a considerable amount of collinearity. This suggests that we need to think about using some form of dimension reduction to find the most relevant variables.</body>
